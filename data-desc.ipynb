# %%
import matplotlib.pyplot as plt
import networkx as nx
import os
import json
import re
# %matplotlib inline
DATA_DIR = './datas/datas'

# %% [markdown]
# ## 数据描述

# %% [markdown]
# ### 数据集简介
# [数据库的历史](https://projects.iq.harvard.edu/chinesecbdb/%E6%AD%B7%E5%8F%B2)
#
# > 郝若貝教授的目標在於利用中國歷史紀錄中保存最豐富之資料(包括公領域之資料如官方歷史記載，及私領域之資料如墓誌銘)，重現單一個人於多脈絡中之面貌：例如，個人作為中心地或行政區劃的本地人或居住者、具有一定的官品和官職，以及作為家族網絡中的一分子。研究者得以透過此一資料庫，探討某特定地方在科舉和出仕方面的表現如何，或將某特定時空下的個人之創作著述聯接起來，或作為其他研究目的之用
#
# 也就是说，其希望建设的是历史人物数据库，个人为中心，具有一定的官品和官职，并且作为家族网络中的一份子。
# 由此说明，该数据库是**个人中心**，具有一定的**社会地位**，**家族网络**
#
# 其提供了sqlite,access的数据库和api，由于相比数据库的字段繁多的，我选择了api，于是写了一个爬虫，便利personid得到相关的数据(422271)。
#
# 数据以人物组织，在给出的[王安石的例子](https://cbdb.fas.harvard.edu/cbdbapi/person.php?id=1762)中，可以看到其包含王安石的生平信息，出生，死亡，入仕、社會區分、亲戚关系等。其中值得一提的是，社會關係关系中包含许多的关系，包括推荐、欣賞/器重等正面的信息外，还包括其政策被Y反對/不支持等负面的信息，这部分信息结合书中第5章关于正负关系讨论，是得我对这个sign graph非常的好奇。

# %%
def basic_statistic():
    '''遍历data文件夹，统计那些PersonInfo不为空的数据'''
    counts = 0
    for fname in os.listdir(DATA_DIR):
        fpath = os.path.join(DATA_DIR, fname)
        with open(fpath) as f:
            try:
                json_data = json.load(f)
                person_data = json_data['Package']['PersonAuthority']['PersonInfo']['Person']
                counts += 1
            except Exception as e:
                pass
#                 print(fpath, e)
    print('total: ', counts)
# basic_statistic()

# %%
def basic_statistic_network():
    '''基本统计network信息'''
    edge_lists = []
    counts = 0
    t = 0
    for fname in os.listdir(DATA_DIR):
        fpath = os.path.join(DATA_DIR, fname)
        with open(fpath) as f:
            try:
                json_data = json.load(f)
                person_data = json_data['Package']['PersonAuthority']['PersonInfo']['Person']
                t += 1
                if 'PersonSocialAssociation' in person_data:
                    person_association = person_data["PersonSocialAssociation"]
                    if 'Association' in person_association:
                        person_assoc = person_association['Association']
                        if isinstance(person_assoc, list):
                            for person in person_association['Association']:
                                if 'AssocPersonId' in person:
                                    #print(fname[:fname.rfind('.')], person['AssocPersonId'])
                                    edge_lists.append((fname[:fname.rfind('.')], person['AssocPersonId']))
                                #if count > 10:break
                                    counts += 1
                        elif isinstance(person_assoc, dict):
                            #print('dict:', fname[:fname.rfind('.')], person_assoc['AssocPersonId'])
                            edge_lists.append((fname[:fname.rfind('.')], person_assoc['AssocPersonId']))
                            counts +=1 
            except Exception as e:
                pass
    print(t, counts, len(edge_lists))
    G = nx.Graph()
    G.add_edges_from(edge_lists)
    #nx.draw(G, with_labels=False, font_weight='bold')
    print(nx.info(G))

# basic_statistic_network()

'''
422271 131879 131879
Name: 
Type: Graph
Number of nodes: 27889
Number of edges: 48004
Average degree:   3.4425

'''
# Out:
# 422271 131879 131879
# Name:
# Type: Graph
# Number of nodes: 27889
# Number of edges: 48004
# Average degree:   3.4425

# %% [markdown]
# ## 朝代划分
#
# 由于整个网络的节点过多，且横跨的时间较长，因此选择根据朝代对数据进行划分。
#
# 其中需要一提的是，由于部分数据可能不详，因此通过以下三个原则对数据进行划分：
#
#     1.标有的朝代
#     2.出生年份在朝代年份内
#     3.死亡年份在朝代年份内

# %%
def handle_dynasty():
    '''
    数据整理为朝代
    '''
    for dynasty in DYNASTY:
        if not os.path.exists('datas/{}'.format(dynasty)):
            os.mkdir('datas/{}'.format(dynasty))
    json_error_f = open('json_error.log', 'w')
    for fname in os.listdir(DATA_DIR):
        fpath = os.path.join(DATA_DIR, fname)
        with open(fpath) as f:
            try:
                json_data = json.load(f)
                person_data = json_data['Package']['PersonAuthority']['PersonInfo']['Person']
                for dynasty in DYNASTY:
                    if is_dynasty(dynasty, person_data, fname):
                        result_path = os.path.join('datas', dynasty, fname)
                        with open(result_path, 'w') as f2:
                            f2.write(json.dumps(person_data))
                        print(fname, dynasty)
            except Exception as e:
                print(fpath, e, file = json_error_f)

# %% [markdown]
# ### 不同朝代的统计结果
# 提取PersonSocialAssociation的Association字段。形成网络，统计不同朝代的网络的节点数和连边数。

# %%
def read_dynasty(dynasty = '宋'):
    edge_lists = []
    count = 0
    t = 0
    dynasty_dir = os.path.join('datas', dynasty)
    for fname in os.listdir(dynasty_dir):
        t += 1
        fpath = os.path.join(dynasty_dir, fname)
        f = open(fpath)
        json_data = json.load(f)
        if 'PersonSocialAssociation' in json_data:
            person_association = json_data["PersonSocialAssociation"]
            if 'Association' in person_association:
                person_assoc = person_association['Association']
                if isinstance(person_assoc, list):
                    for person in person_association['Association']:
                        if 'AssocPersonId' in person:
                            #print(fname[:fname.rfind('.')], person['AssocPersonId'])
                            edge_lists.append((fname[:fname.rfind('.')], person['AssocPersonId']))
                        count +=1
                        #if count > 10:break
                elif isinstance(person_assoc, dict):
                    #print('dict:', fname[:fname.rfind('.')], person_assoc['AssocPersonId'])
                    edge_lists.append((fname[:fname.rfind('.')], person_assoc['AssocPersonId']))
    print(count, t)
    G = nx.Graph()
    G.add_edges_from(edge_lists)
    #nx.draw(G, with_labels=False, font_weight='bold')
    print(nx.info(G)) 
    return G

# print('唐朝')    
# read_dynasty('唐')

# print('宋朝')    
# read_dynasty('宋')

# print('元朝')    
# read_dynasty('元')

# print('明朝')    
# read_dynasty('明')

# print('清朝')    
# read_dynasty('清')


# 唐朝
# 288 50402
# Name: 
# Type: Graph
# Number of nodes: 365
# Number of edges: 286
# Average degree:   1.5671
# 宋朝
# 78652 53531
# Name: 
# Type: Graph
# Number of nodes: 17114
# Number of edges: 30330
# Average degree:   3.5445
# 元朝
# 23083 23228
# Name: 
# Type: Graph
# Number of nodes: 6424
# Number of edges: 11864
# Average degree:   3.6936
# 明朝
# 27534 189622
# Name: 
# Type: Graph
# Number of nodes: 8350
# Number of edges: 14609
# Average degree:   3.4992
# 清朝
# 3920 89435
# Name: 
# Type: Graph
# Number of nodes: 3128
# Number of edges: 3059
# Average degree:   1.9559
g = read_dynasty('唐')
nx.write_gexf(g, "tang.gexf")
# Out:
# 唐朝
# 288 50402
# Name:
# Type: Graph
# Number of nodes: 365
# Number of edges: 286
# Average degree:   1.5671
# 宋朝
# 78652 53531
# Name:
# Type: Graph
# Number of nodes: 17114
# Number of edges: 30330
# Average degree:   3.5445
# 元朝
# 23083 23228
# Name:
# Type: Graph
# Number of nodes: 6424
# Number of edges: 11864
# Average degree:   3.6936
# 明朝
# 27534 189622
# Name:
# Type: Graph
# Number of nodes: 8350
# Number of edges: 14609
# Average degree:   3.4992
# 清朝
# 3920 89435
# Name:
# Type: Graph
# Number of nodes: 3128
# Number of edges: 3059
# Average degree:   1.9559

# %%
def vis_network(nodes_num = 100, graph):
    '''
    实现网络的可视化，通过随机采样的方式对数据进行基本的可视化。
    当然更为合理的方式是将网络导入到gephi中。
    '''
    nodes = graph.nodes()
    samples = np.random.randint(0, len(nodes), nodes_num)
    samples_nodes = nodes[samples]
    subgraph = graph.subgraph(samples_nodes)

# %% [markdown]
# #### 将家族关系考虑进网络中的统计结果
#
# 有之前的统计结果可以看出，网络主要在宋元明。而弱不考虑家族关系的话，这个网络是社交网络。
# 但是其实应该将家族的网络加入到社会网络中，比较合理。

# %%
from collections import defaultdict
def statistic_relation():
    relations = set()
    relations_codes = set()
    relations_c = defaultdict(int)
    error = 0
    for fname in os.listdir(DATA_DIR):
        fpath = os.path.join(DATA_DIR, fname)
        with open(fpath) as f:
            try:
                json_data = json.load(f)
                if 'Person' not in json_data['Package']['PersonAuthority']['PersonInfo']:
                    continue
                person_data = json_data['Package']['PersonAuthority']['PersonInfo']['Person']
                if 'PersonSocialAssociation' in person_data:
                    person_association = person_data["PersonSocialAssociation"]
                    if 'Association' in person_association:
                        person_assoc = person_association['Association']
                        if isinstance(person_assoc, list):
                            for person in person_association['Association']:
                                if 'AssocName' in person and 'AssocCode' in person:
                                    relations.add(person['AssocName'])
                                    relations_codes.add(person['AssocCode'])
                                    tmp = (person['AssocName'], person['AssocCode'])
                                    relations_c[tmp] += 1
                        elif isinstance(person_assoc, dict):
                            relations.add(person['AssocName'])
                            relations_codes.add(person['AssocCode'])
                            tmp = (person['AssocName'], person['AssocCode'])
                            relations_c[tmp] += 1
            except json.decoder.JSONDecodeError as e:
                error += 1
    print(len(relations), len(relations_codes), len(relations_c))
    print(relations)
    print(relations_codes)
    for r in relations_c:
        print(r[0], ',', r[1], ',', relations_c[r])
statistic_relation()
# Out:
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# string indices must be integers
# 440 447 447
# {'', '為Y之家僕', '其生祠由Y作記', '其（或追隨者）殺害Y', '為Y作齋、堂銘', '下屬為Y', '拒為Y掾屬', '其學得到Y之讚揚', '攻擊道學', '上司為Y', '教授Y', '以詩諷忤Y', '奪Y之妻', '被Y在遺表中推薦', '教授Y之學', '忌/惡', '鞫治', '游説Y被拒絕', '神道碑跋由Y所作', '為Y之生祠作記', '家僕為Y', '被Y推薦參加制科考試', '墓誌銘係由Y向他人（第三方）求得', '其政策得到Y的支持[併入26]', '逃離Y的統治區', '遺奏推薦', '不合', '稱道Y之文風', '齋、堂銘由Y所作', '為Y之潛邸舊人', '為Y作壙記', '軍隊得到Y之贍給', '求Y為他人（第三方）作神道碑', '諂事Y', '被Y陷害', '辟', '被Y逮捕', '為Y作諡議', '遭Y黨羽的攻訐', '被Y欣賞/器重', '遭Y反秦檜勢力排擠', '得到Y之幫助', '支持', '抵禦或討平叛軍Y', '與他的交往導致Y受牽連', '獻策於Y', '下令處決', '著述由Y刊刻', '為Y取名、字', '排Y之學', '收到Y的啓', '受Y之請作序、記', '從Y學', '與Y遊', '彈劾', '指教Y', '節行為Y所稱道', '家傳為Y所作', '收到Y的贈詩、文', '攻訐[併入15]', '以文章、學問受知於', '逮捕', '對他的赦免遭到Y的反對', '受經於Y', '由Y代作文', '反對/不支持Y的政策', '為Y之書、畫作跋', '贈Y物', '著作被Y評論', '同學、同門', '合撰(編)著作', '為Y之神道碑作額篆', '為Y作廟碑記', '職業被Y繼承', '求他人（第三方）為Y作神道碑', '為Y作祭文', '門客為Y', '為Y乞某事', '採Y之著述', '稱道Y之節行', '題Y的書帖', '為Y作碑陰', '其冤因Y得明', '從Y處收到賀詞 (occasion)', '詩社成員', '詩文跋由Y所作', '相識', '同鄉', '被Y以醫術所事', '為Y作名說', '禮待', '因與Y的交往受牽連', '從Y遊', '其學為Y所私淑', '答Y啓', '得到贈畫', '為Y之弟子', '被Y獻詩集', '畫風師法Y', '被Y蠱惑', '為Y祭文作跋', '為Y之婢', '科舉次第由Y決定', '受Y之軍事支持', '傳記作者為Y', '其主政期中Y出仕 [暫時保留，待刪除]', '書風為Y所模仿', '為Y撰寫學術源宗', '為Y所忌/惡', '求Y為他人（第三方）作墓誌銘', '同道', '研讀Y的著作', '結義', '論學', '拒為Y之黨', '黨羽為Y', '私淑Y之學', '送別', '根據Y的命令被處決', '為Y之學生', '被致書由Y', '醫愈', '著述由Y校訂', '婢為Y', '其學由Y傳授學生', '致Y啓', '為Y作神道碑', '為Y學派的成員', '為Y作挽詩、詞', '獻詩集給Y', '為使團副使Y的正使', '書之題詞由Y所作', '家譜由Y作序', '陷害Y', '受Y的請求為他人（第三方）作墓誌銘', '題Y之畫作', '受Y的請求為他人（第三方）作神道碑', '門人為Y', '被指為Y之同犯', '為Y之世交父執', '籌劃謀殺', '詩文由Y編輯', '受到Y拜訪', '贈詩、文', '被Y諂事', '稱道Y的書、畫', '為Y之建築物題詠、記、命名', '聘Y執教官學、書院', '評論Y之著作', '讚揚Y之學', '被Y鞫治', '喪事由Y經紀', '為Y之行狀作跋', '為Y所葬', '挽詩、詞由Y所作', '為Y之假子(養子)', '建議處決Y', '文風為Y所稱道', '神道碑由Y所作', '相唱和', '為Y之謀士', '文風效法Y', '為Y之義莊規矩作序', '向Y購買', '其後代出於Y之門', '書、畫為Y所稱道', '墓表由Y所作', '潛邸舊人為Y', '收到Y所獻詩、文、書', '學生為Y', '經紀Y之喪', '為Y之書題詞', '政見趨同', '年譜由Y所作', '反對/攻訐', '賣給Y', 'Y自其統治區中逃離', '墓誌銘由Y所作', '為Y建立祠廟', '批評', '書跋由Y所作', '行狀跋由Y所作', '答Y書', '墓表跋由Y所作', '為Y作哀辭 [併入167]', '神道碑係由Y向他人（第三方）求得', '為Y之門人', '祭文跋由Y所作', '為Y作道觀記', '其學術作品由Y編輯', '祠記由Y所作', '為Y之詩文作跋', '反對赦免', '元符上書入籍者', '向Y求墓表', '王安石新法支持者', '以Y之志業自任', '詩作為Y所稱道', '排擠', '與Y攀親戚敘族屬', '神道碑序由Y所作', '家傳跋由Y所作', '為Y作傳', '其學為Y所宗', '稱道Y之文章、學問', '模仿Y的書風', '由Y陪伴至貶所', '為Y作墓誌銘', '欣賞/器重', '政績為Y所稱道', '為Y之墓誌銘作跋', '接受Y之納降', '遭Y反韓侂胄勢力排擠', '編輯Y之詩文', '同年友', '為Y作年譜', '推薦Y參加制科考試', '被Y軍事對抗Y', '為Y所辟', '(暫時保留，待刪除：吏部供職)', '王安石新法反對者', '哀辭由Y所作', '弟子為Y', '錄Y為假子(養子)', '被Y得罪', '為Y神道碑作序', '遭到Y的反對/攻訐', '會面的邀請被Y拒絕', '以Y為謀士', '祭文由Y所作', '收到Y的答書', '壙記由Y所作', '得到Y的喜爱', '處決', '葬', '為Y侍女', '養育', '從遊者為Y', '求他人（第三方）為Y作墓誌銘', '神道碑的書法由Y所作', '代Y作文', '廟碑記由Y所作', '建築物得到Y的題詠、記、命名', '拒絕在Y主政的政府中任職', '與Y旅遊', '與Y爭權', '著述為Y所採', '其書帖由Y作題', '拒絕Y的聯姻建議', '拒Y游説', '行狀由Y所作', '軍事對抗Y', '題Y之墓', '文風為Y所效法', '名說由Y所作', '拒絕會面', '為Y作臨別贈言(送別詩、序)', '幕僚為Y', '為Y的墓誌銘作額篆', '為Y作世系碑記', '墓表序由Y所作', '墓誌銘由Y作跋', '遭Y蔡京勢力排擠', '友', '欲辟Y為幕僚但被拒絕', '為宦官Y所事', '遭Y攻訐 [併入16]', '得到Y的擁立', '碑陰為Y所作', '聘Y主家之教席', '與Y共赴難', '贈畫', '畫風為Y所師法', '接受Y的錢物', '題畫詩文的作者為Y', '被Y以詩諷忤', '受Y之禮待', '為Y作家傳', '以Y為侍女', '與Y結黨', '為Y作墓表', '擁立Y', '家主為Y', '字說、名述由Y所作', '為Y墓誌銘作序', '為Y作哀辭', '同場屋/同應舉', '聯姻建議被Y拒絕', '其學為Y所排', '為Y之考官', '被Y（或追隨者）殺害', '恩主是Y', '決定Y的科舉次第', '為Y之家傳作跋', '(暫時保留,待日後分入 429, 430, 431, 432)', '為Y之義女', '臨別得到Y所作贈言(送別詩、序)', '受Y之贈物', '為Y作行狀', '被Y醫愈', '其黨攻訐Y', '為Y之神道碑作書', 'Y為之建立祠廟', '其著作為Y所研讀', '匾額、器銘由Y所篆', '妻被Y奪', 'Y與之攀親戚敘族屬', '為Y之門客', '傳經於Y', '敗於', '該學派的成員為Y', '以宦官事Y', '書序由Y所作', '蠱惑Y', '稱帝為Y所反對', '致書Y', '為Y作學記（書院記）', '奏錄Y之文', '為Y之收藏作跋', '上奏論Y', '墓由Y題', '獻文、書于Y', '學術源宗由Y撰寫', '拜訪', '主Y家之教席', '為Y作祠記', '為Y之部將', '世系碑記由Y所作', '學記（書院記）由Y所作', '戰勝', '為Y之家譜作序', '向Y問學', '喜爱', '向Y致賀', '研修理學', '神道碑額篆由Y所作', '詩文序由Y所作', '請Y作序、記', '世交父執為Y', '以Y言得到封贈', '得罪Y', '其文為Y所奏錄', '被Y籌劃謀殺', '家傳序由Y所作', '墓誌銘序由Y所作', '義莊規矩序由Y所作', '拒絕在Y的主政期出仕', '為Y作祝詞', '傳Y之學', '稱道Y之政績', '部將為Y', '入元祐黨籍者', '出財贍給Y之軍', '降於', '被送別', '慶元被禁的「僞學」人士', '收到Y的答啓', '同僚', '編輯Y的學術作品', '戰友', '硯銘由Y所作', '為Y神道碑作跋', '其同犯被指為Y', '書、畫由Y作跋', '為Y之幕僚', '幫助Y', '為Y家譜作序', '佛寺記由Y所作', '向Y借書', '被Y批評', '為Y之家傳作序', '慶元黨人的指控者', '為Y所佑', '對Y執弟子禮', '諡議由Y所作', '為Y作佛寺記', '副Y出使', '祝詞由Y所作', '刊刻Y之著述', '得到Y的支持', '受Y之弟子禮', '為Y作畫贊(畫像記)', '被Y養育', '推薦', '聘Y執教族學', '義女為Y', '給Y錢物', '借書給Y', '遭Y排擠', '道觀記由Y所作', '墓誌銘額篆由Y所作', '遭 ...
# {'19', '416', '152', '415', '174', '459', '412', '483', '550', '517', '42', '113', '306', '367', '12', '68', '299', '515', '149', '48', '572', '362', '298', '60', '580', '95', '546', '578', '359', '442', '587', '540', '277', '207', '410', '516', '34', '343', '528', '548', '465', '213', '193', '397', '507', '210', '8', '228', '195', '46', '382', '0', '227', '323', '199', '148', '365', '441', '456', '14', '525', '297', '302', '565', '480', '17', '444', '559', '324', '76', '381', '257', '451', '254', '237', '130', '211', '292', '336', '405', '160', '579', '464', '461', '454', '458', '439', '497', '240', '321', '259', '32', '16', '156', '86', '510', '276', '158', '65', '519', '24', '561', '434', '406', '582', '159', '433', '69', '248', '514', '467', '141', '31', '544', '537', '49', '85', '252', '363', '396', '107', '322', '499', '47', '468', '352', '145', '59', '494', '220', '334', '168', '502', '511', '358', '225', '89', '349', '139', '448', '549', '437', '547', '470', '390', '583', '249', '37', '486', '529', '429', '140', '399', '351', '344', '231', '524', '440', '278', '462', '490', '553', '4', '189', '247', '455', '223', '527', '30', '522', '87', '71', '269', '129', '243', '88', '186', '41', '22', '575', '431', '143', '127', '536', '305', '571', '198', '428', '138', '460', '38', '530', '551', '250', '279', '150', '341', '27', '564', '21', '146', '560', '364', '489', '354', '301', '484', '503', '400', '557', '568', '253', '294', '239', '284', '450', '556', '581', '23', '35', '84', '518', '25', '268', '251', '280', '214', '574', '333', '219', '531', '273', '197', '315', '316', '20', '50', '563', '481', '166', '523', '209', '436', '426', '356', '479', '40', '136', '36', '504', '287', '562', '262', '105', '5', '355', '421', '491', '424', '422', '13', '339', '17370', '44', '432', '532', '7', '270', '427', '569', '418', '293', '505', '187', '10', '53', '184', '425', '520', '114', '183', '137', '541', '473', '260', '56', '190', '508', '261', '256', '445', '26', '506', '475', '55', '67', '244', '414', '534', '162', '157', '304', '163', '274', '438', '423', '132', '404', '75', '172', '413', '430', '449', '554', '1', '104', '501', '235', '398', '476', '419', '224', '542', '236', '463', '420', '391', '543', '435', '173', '472', '106', '204', '478', '94', '196', '585', '108', '282', '64', '471', '573', '487', '526', '126', '495', '493', '185', '512', '342', '117', '241', '535', '417', '539', '238', '469', '258', '309', '226', '545', '154', '577', '144', '555', '488', '120', '303', '521', '147', '9', '380', '18', '128', '73', '232', '2', '335', '15', '482', '409', '466', '474', '242', '586', '181', '533', '70', '443', '167', '999', '74', '39', '133', '361', '11', '558', '188', '131', '66', '300', '552', '403', '283', '58', '194', '33', '498', '350', '509', '576', '217', '205', '310', '379', '61', '275', '45', '485', '151', '118', '43', '57', '496', '457', '584', '142', '570', '340', '161', '29', '218', '206', '500', '175', '513', '97', '83', '72', '119', '263', '208', '366', '155', '538', '180', '492'}
# (暫時保留，待刪除) , 31 , 2
# 為Y墓表作跋 , 422 , 3
# 畫風師法Y , 473 , 124
# 為Y之弟子 , 36 , 116
# 排擠 , 29 , 196
# 奪Y之妻 , 460 , 3
# 稱道Y的書、畫 , 476 , 19
# 某事由Y所乞 , 552 , 104
# 為Y之謀士 , 118 , 4
# 同僚 , 197 , 538
# 為Y之考官 , 558 , 20
# 為Y之學生 , 22 , 1314
# 門客為Y , 131 , 170
# 為Y篆匾額、器銘 , 483 , 91
# 給Y錢物 , 448 , 8
# 教授Y之學 , 258 , 4
# 蠱惑Y , 507 , 1
# 拜訪 , 339 , 101
# 為Y作道觀記 , 556 , 86
# 受Y的請求為他人（第三方）作神道碑 , 546 , 1
# 忌/惡 , 83 , 102
# 被Y鞫治 , 156 , 14
# 上司為Y , 481 , 167
# 其志業由Y傳承 , 40 , 29
# 建議處決Y , 128 , 14
# 行狀跋由Y所作 , 524 , 13
# 為Y之書、畫作跋 , 149 , 851
# 以Y為謀士 , 119 , 3
# 被Y（或追隨者）殺害 , 210 , 79
# 攻訐[併入15] , 183 , 2
# 借書給Y , 512 , 6
# 其學為Y所私淑 , 257 , 37
# 在Y的主政期出仕 [暫時保留，待刪除] , 249 , 7
# 家傳為Y所作 , 396 , 88
# (暫時保留,待日後分入 429, 430, 431, 432) , 280 , 3
# 為Y之書題詞 , 580 , 211
# 墓誌銘由Y作跋 , 333 , 55
# 得到Y之幫助 , 528 , 39
# 傳經於Y , 218 , 28
# 其書帖由Y作題 , 440 , 58
# 求他人（第三方）為Y作神道碑 , 547 , 2
# 節行為Y所稱道 , 68 , 128
# 聘Y執教官學、書院 , 499 , 51
# 家譜由Y作序 , 275 , 74
# 編輯Y的學術作品 , 456 , 40
# 出財贍給Y之軍 , 195 , 3
# 為Y之部將 , 64 , 197
# 與Y共赴難 , 522 , 218
# 被Y奏論 , 554 , 136
# 神道碑額篆由Y所作 , 241 , 25
# 傳記作者為Y , 132 , 2058
# 編輯Y之詩文 , 341 , 18
# 軍隊得到Y之贍給 , 196 , 2
# 為Y作行狀 , 426 , 1118
# 廟碑記由Y所作 , 161 , 167
# 被Y諂事 , 587 , 4
# 為Y之詩文作跋 , 469 , 1113
# 軍事對抗Y , 584 , 78
# 書、畫為Y所稱道 , 475 , 28
# 降於 , 381 , 26
# 為Y所忌/惡 , 84 , 107
# 為Y作義莊記 , 199 , 16
# 以Y言得到封贈 , 352 , 4
# 與Y旅遊 , 555 , 112
# 被Y處決 , 205 , 6
# 對Y執弟子禮 , 193 , 28
# 為Y作諡議 , 188 , 249
# 葬 , 220 , 15
# Y與之攀親戚敘族屬 , 571 , 1
# 為Y乞某事 , 551 , 77
# 奏錄Y之文 , 487 , 20
# 門人為Y , 20 , 657
# 被Y陷害 , 472 , 101
# 為Y之義莊規矩作序 , 247 , 1
# 其學為Y所宗 , 209 , 60
# 潛邸舊人為Y , 496 , 8
# 為Y作家傳 , 397 , 93
# 幫助Y , 527 , 44
# 職業被Y繼承 , 53 , 2
# 神道碑係由Y向他人（第三方）求得 , 548 , 2
# 為Y作墓誌銘 , 44 , 10189
# 受Y之禮待 , 364 , 58
# 文風為Y所稱道 , 173 , 43
# 被Y養育 , 86 , 13
# 拒絕在Y的主政期出仕 , 107 , 109
# 為Y之門客 , 130 , 196
# 稱道Y之節行 , 69 , 130
# 與Y爭權 , 294 , 4
# 為Y作名說 , 398 , 2
# 讚揚Y之學 , 140 , 46
# 收到Y的答啓 , 436 , 62
# 為Y撰寫學術源宗 , 72 , 6
# 題Y之墓 , 517 , 6
# 採納Y之獻策 , 520 , 32
# 被Y醫愈 , 48 , 7
# 受Y的請求為他人（第三方）作墓誌銘 , 155 , 25
# 墓由Y題 , 518 , 5
# 為Y作傳 , 133 , 2398
# 為Y作世系碑記 , 151 , 236
# 墓誌銘係由Y向他人（第三方）求得 , 544 , 2
# 匾額、器銘由Y所篆 , 484 , 124
# 為Y所佑 , 493 , 11
# 未詳 , 0 , 353
# 研讀Y的著作 , 361 , 19
# 獻策於Y , 519 , 20
# 其後代出於Y之門 , 309 , 3
# 著述由Y校訂 , 573 , 13
# 經紀Y之喪 , 224 , 9
# 答Y書 , 431 , 1221
# 畫贊(畫像記)由Y所作 , 427 , 627
# 其同犯被指為Y , 464 , 3
# 墓表跋由Y所作 , 421 , 4
# 家僕為Y , 563 , 8
# 為Y所聘執教族學 , 302 , 6
# 游説Y被拒絕 , 492 , 2
# 為Y墓誌銘作序 , 414 , 8
# 為Y之建築物題詠、記、命名 , 443 , 2447
# 為Y之收藏作跋 , 465 , 20
# 舉辦的鄉Ⅰ禮得到Y所作之序 , 283 , 2
# (暫時保留，待刪除：吏部供職) , 356 , 331
# 遭Y反韓侂胄勢力排擠 , 168 , 3
# 教授Y , 232 , 373
# 拒絕會面 , 142 , 32
# 家僕為Y , 454 , 3
# 禮待 , 363 , 56
# 贈詩、文 , 437 , 2927
# 得到Y的喜爱 , 358 , 35
# 文風為Y所效法 , 58 , 31
# 接受Y的錢物 , 449 , 10
# 為Y作墓表 , 410 , 1655
# 祠記由Y所作 , 561 , 730
# 哀辭由Y所作 , 166 , 512
# 名說由Y所作 , 403 , 4
# 文風效法Y , 57 , 36
# 拒Y游説 , 491 , 4
# 遭Y蔡京勢力排擠 , 254 , 6
# 其政策得到Y的支持[併入26] , 274 , 4
# 鞫治 , 157 , 14
# 弟子為Y , 37 , 146
# 陷害Y , 471 , 85
# 相唱和 , 114 , 727
# 為Y之家傳作跋 , 525 , 3
# 為Y作挽詩、詞 , 424 , 451
# 祝詞由Y所作 , 148 , 127
# 建築物得到Y的題詠、記、命名 , 444 , 2831
# 提議封贈Y , 351 , 5
# 邀Y入黨但遭到拒絕 , 304 , 3
# 向Y問學 , 467 , 73
# 私淑Y之學 , 256 , 49
# 模仿Y的書風 , 380 , 15
# 以Y之志業自任 , 41 , 33
# 研修理學 , 42 , 18
# 著作被Y評論 , 530 , 111
# 祭文跋由Y所作 , 537 , 2
# 稱道Y之文風 , 172 , 41
# 神道碑的書法由Y所作 , 174 , 24
# 同場屋/同應舉 , 120 , 18
# 其學由Y所傳 , 127 , 59
# 與Y遊 , 277 , 272
# 幕僚為Y , 67 , 107
# 為Y家譜作序 , 400 , 2
# 籌劃謀殺 , 59 , 13
# 遭到Y的反對/攻訐 , 16 , 348
# 得到贈畫 , 504 , 5
# 被Y軍事對抗Y , 585 , 71
# 祭文由Y所作 , 146 , 3975
# 為Y作神道碑 , 406 , 1076
# 為Y作年譜 , 238 , 55
# 書風為Y所模仿 , 379 , 12
#  , 999 , 213
# 傳Y之學 , 126 , 69
# 校訂Y之著述 , 572 , 3
# 為Y作祝詞 , 147 , 125
# 受Y之請作序、記 , 510 , 21
# 義莊規矩序由Y所作 , 248 , 1
# 被Y以詩諷忤 , 75 , 5
# 同年友 , 10 , 461
# 家主為Y , 455 , 1
# 醫愈 , 47 , 10
# 為Y之潛邸舊人 , 495 , 12
# 被Y蠱惑 , 508 , 1
# 致書Y , 429 , 3302
# 軍事支持Y , 582 , 98
# 部將為Y , 65 , 225
# 為Y之幕僚 , 66 , 102
# 受Y之軍事支持 , 583 , 162
# 黨魁為Y , 8 , 44
# 代Y作文 , 489 , 24
# 臨別得到Y所作贈言(送別詩、序) , 163 , 3520
# 諡議由Y所作 , 187 , 233
# Y為之建立祠廟 , 253 , 27
# 被Y欣賞/器重 , 17 , 571
# 遭Y排擠 , 30 , 199
# 王安石新法支持者 , 287 , 3
# 詩文由Y編輯 , 342 , 11
# 其黨攻訐Y , 139 , 2
# 同會 , 268 , 73
# 為Y祭文作跋 , 538 , 7
# 題畫詩文的作者為Y , 442 , 42
# 叛軍遭到Y的抵禦或討平 , 207 , 81
# 畫風為Y所師法 , 474 , 177
# 答Y啓 , 435 , 61
# 反對Y稱帝 , 513 , 37
# 同鄉 , 94 , 102
# 批評 , 269 , 44
# 下屬為Y , 482 , 163
# 家傳跋由Y所作 , 526 , 3
# 稱道Y之政績 , 540 , 389
# 請Y作序、記 , 509 , 40
# 該學派的成員為Y , 35 , 120
# 慶元黨人的指控者 , 305 , 38
# 為Y作壙記 , 463 , 67
# 其文為Y所奏錄 , 488 , 22
# 聘Y主家之教席 , 214 , 17
# 論學 , 108 , 276
# 墓表由Y所作 , 409 , 1312
# 為Y神道碑作序 , 416 , 6
# 被Y推薦 , 14 , 1060
# 得罪Y , 515 , 177
# 政績為Y所稱道 , 539 , 328
# 由Y陪伴至貶所 , 316 , 2
# 為Y所葬 , 219 , 17
# 獻文、書于Y , 505 , 42
# 為Y明冤 , 485 , 21
# 為Y舉辦的鄉Ⅰ禮作序 , 284 , 2
# 向Y求墓表 , 412 , 1
# 妻被Y奪 , 461 , 1
# 向Y致賀 , 390 , 630
# 墓誌銘額篆由Y所作 , 531 , 1
# 為Y之墓誌銘作跋 , 334 , 39
# 門人為Y之後代 , 310 , 3
# 神道碑序由Y所作 , 415 , 7
# 家傳序由Y所作 , 578 , 7
# 稱道Y之文章、學問 , 293 , 62
# 為Y之生祠作記 , 497 , 86
# 擁立Y , 262 , 3
# 稱帝為Y所反對 , 514 , 18
# 決定Y的科舉次第 , 185 , 19
# 下令處決 , 181 , 11
# 墓誌銘序由Y所作 , 413 , 8
# 為Y之神道碑作額篆 , 242 , 17
# 得到Y的支持 , 26 , 301
# 被Y在遺表中推薦 , 105 , 1
# 收到Y的答書 , 432 , 1545
# 遭Y新法支持者排擠 , 97 , 7
# 是Y的恩主 , 4 , 141
# 從Y遊 , 49 , 384
# 著述為Y所採 , 323 , 8
# 逃離Y的統治區 , 299 , 2
# 神道碑由Y所作 , 405 , 1066
# 從遊者為Y , 50 , 390
# 求他人（第三方）為Y作墓誌銘 , 543 , 3
# 受Y之贈物 , 534 , 16
# 其學術作品由Y編輯 , 457 , 28
# 慶元被禁的「僞學」人士 , 306 , 59
# 其政策被Y反對/不支持 , 137 , 281
# 年譜由Y所作 , 237 , 112
# 考官為Y , 559 , 40
# 字說、名述由Y所作 , 89 , 455
# 欣賞/器重 , 18 , 583
# 著述由Y刊刻 , 542 , 22
# (暫時保留，待刪除) , 350 , 1
# 宗Y之學 , 208 , 88
# 從Y處收到賀詞 (occasion) , 391 , 664
# 反對赦免 , 189 , 8
# 以詩諷忤Y , 76 , 7
# 其（或追隨者）殺害Y , 211 , 71
# 受到Y拜訪 , 340 , 98
# 為Y作碑陰 , 322 , 52
# 戰勝 , 343 , 34
# 採Y之著述 , 324 , 4
# 科舉次第由Y決定 , 186 , 15
# 刊刻Y之著述 , 541 , 16
# 致Y啓 , 433 , 160
# 贈畫 , 503 , 5
# 彈劾 , 11 , 400
# 攻擊道學 , 85 , 2
# 求Y為他人（第三方）作神道碑 , 545 , 1
# 為Y神道碑作跋 , 418 , 3
# 其處決係由Y建議 , 129 , 14
# 義莊記由Y所作 , 198 , 20
# 推薦Y參加制科考試 , 56 , 10
# 與Y結黨 , 21 , 86
# 支持 , 27 , 305
# (暫時保留，待刪除) , 349 , 2
# 其學得到Y之讚揚 , 141 , 46
# 挽詩、詞由Y所作 , 423 , 486
# 辟 , 24 , 99
# 收到Y的贈詩、文 , 438 , 3383
# 詩文序由Y所作 , 480 , 1021
# 為Y作學記（書院記） , 459 , 538
# 為宦官Y所事 , 355 , 4
# 為Y作臨別贈言(送別詩、序) , 162 , 3623
# 為Y作祭文 , 145 , 3667
# 為Y之假子(養子) , 569 , 12
# 為Y作祠記 , 560 , 635
# 元符上書入籍者 , 2 , 102
# 世系碑記由Y所作 , 152 , 174
# 為Y作佛寺記 , 239 , 508
# 得到Y的擁立 , 263 , 5
# 由Y代作文 , 490 , 38
# 為Y作字說、名述 , 88 , 455
# 被Y以醫術所事 , 478 , 2
# 被Y彈劾 , 12 , 385
# 稱道Y的詩作 , 71 , 93
# 獻詩集給Y , 576 , 5
# 護佑Y , 494 , 14
# 為Y建立祠廟 , 252 , 32
# 結義 , 521 , 3
# 為Y所辟 , 25 , 95
# 為Y所聘執教官學、書院 , 500 , 69
# 處決 , 204 , 8
# 被Y逮捕 , 158 , 12
# 評論Y之著作 , 529 , 80
# (暫時保留，待刪除) , 236 , 1
# 為Y作哀辭 [併入167] , 38 , 8
# 碑陰為Y所作 , 321 , 53
# 為使團副使Y的正使 , 279 , 13
# 拒為Y掾屬 , 260 , 27
# 同學、同門 , 117 , 357
# 被Y籌劃謀殺 , 60 , 19
# 與他的交往導致Y受牽連 , 244 , 42
# 其冤因Y得明 , 486 , 27
# (暫時保留，待刪除) , 235 , 1
# 硯銘由Y所作 , 226 , 47
# 為Y作齋、堂銘 , 298 , 123
# 為Y作廟碑記 , 160 , 188
# 書序由Y所作 , 33 , 4774
# 為Y作硯銘 , 225 , 33
# 神道碑跋由Y所作 , 417 , 2
# 受經於Y , 217 , 33
# 為Y墓表作序 , 420 , 20
# 從Y學 , 231 , 419
# 名、字由Y所取 , 536 , 23
# 詩作為Y所稱道 , 70 , 94
# 為Y之行狀作跋 , 523 , 7
# 題Y之畫作 , 441 , 51
# 遭Y攻訐 [併入16] , 184 , 2
# 以文章、學問受知於 , 292 , 62
# 推薦 , 13 , 1171
# 行狀由Y所作 , 425 , 1313
# 哀辭由Y所作[併入166] , 39 , 10
# 其著作為Y所研讀 , 362 , 14
# 書之題詞由Y所作 , 581 , 284
# 為Y作畫贊(畫像記) , 428 , 571
# 逮捕 , 159 , 19
# 為Y之義女 , 549 , 3
# 為Y所著書作序 , 32 , 4323
# 黨羽為Y , 7 , 45
# 遭Y黨羽的攻訐 , 138 , 4
# 從Y至貶所 , 315 , 2
# 為Y之家譜作序 , 276 , 72
# 以宦官事Y , 354 , 5
# 友 , 9 , 1460
# 壙記由Y所作 , 462 , 87
# 喜爱 , 359 , 27
# 合撰(編)著作 , 251 , 125
# 被Y得罪 , 516 , 123
# 拒為Y之黨 , 303 , 4
# 收藏品由Y作跋 , 466 , 29
# 與Y攀親戚敘族屬 , 570 , 3
# 為Y之門人 , 19 , 490
# 其生祠由Y作記 , 498 , 99
# 養育 , 87 , 10
# 為Y作哀辭 , 167 , 511
# 恩主是Y , 5 , 132
# 為Y的墓誌銘作額篆 , 532 , 1
# 求Y為他人（第三方）作墓誌銘 , 154 , 24
# 遭Y反秦檜勢力排擠 , 144 , 3
# 其學由Y傳授學生 , 259 , 5
# 其學為Y所排 , 228 , 13
# 家譜由Y作序 , 399 , 2
# 被Y批評 , 270 , 35
# 因與Y的交往受牽連 , 243 , 54
# 主Y家之教席 , 213 , 17
# 指教Y , 468 , 65
# 不合 , 61 , 152
# 拒絕Y的聯姻建議 , 336 , 13
# 聯姻建議被Y拒絕 , 335 , 9
# Y自其統治區中逃離 , 300 , 5
# 被Y獻詩集 , 577 , 4
# 接受Y之納降 , 382 , 24
# 向Y購買 , 450 , 2
# 以Y為侍女 , 366 , 8
# 詩社成員 , 113 , 30
# 道觀記由Y所作 , 557 , 77
#  , 17370 , 3
# 錄Y為假子(養子) , 568 , 3
# 為Y之神道碑作書 , 175 , 16
# 遺奏推薦 , 104 , 1
# 為Y學派的成員 , 34 , 144
# 排Y之學 , 227 , 13
# 為Y之婢 , 574 , 5
# 諂事Y , 586 , 30
# 相識 , 95 , 165
# 收到Y的啓 , 434 , 204
# 婢為Y , 575 , 15
# 為Y之世交父執 , 565 , 39
# 墓表序由Y所作 , 419 , 14
# 對他的赦免遭到Y的反對 , 190 , 1
# 贈Y物 , 533 , 9
# 喪事由Y經紀 , 223 , 11
# 學術源宗由Y撰寫 , 73 , 4
# 被致書由Y , 430 , 3624
# 被指為Y之同犯 , 282 , 2
# 佛寺記由Y所作 , 240 , 276
# 抵禦或討平叛軍Y , 206 , 87
# 詩文跋由Y所作 , 470 , 1375
# 支持Y的政策 [併入27] , 273 , 3
# 被Y推薦參加制科考試 , 55 , 11
# 反對/不支持Y的政策 , 136 , 297
# 書、畫由Y作跋 , 150 , 833
# 書跋由Y所作 , 45 , 4111
# 為Y之家僕 , 562 , 5
# 賣給Y , 451 , 2
# 為Y侍女 , 365 , 5
# 向Y借書 , 511 , 7
# 學生為Y , 23 , 1433
# 題Y的書帖 , 439 , 50
# 同道 , 445 , 138
# 政見趨同 , 367 , 54
# 被送別 , 502 , 5
# 墓誌銘由Y所作 , 43 , 8502
# 世交父執為Y , 564 , 48
# 敗於 , 344 , 28
# 齋、堂銘由Y所作 , 297 , 139
# 受Y之弟子禮 , 194 , 25
# 會面的邀請被Y拒絕 , 143 , 25
# 為Y所作詩文作序 , 479 , 860
# 聘Y執教族學 , 301 , 6
# 義女為Y , 550 , 4
# 其主政期中Y出仕 [暫時保留，待刪除] , 250 , 19
# 上奏論Y , 553 , 93
# 為Y所著書作跋 , 46 , 3868
# 收到Y所獻詩、文、書 , 506 , 27
# 欲辟Y為幕僚但被拒絕 , 261 , 21
# 學記（書院記）由Y所作 , 458 , 629
# 入元祐黨籍者 , 1 , 112
# 根據Y的命令被處決 , 180 , 6
# 副Y出使 , 278 , 17
# 拒絕在Y主政的政府中任職 , 106 , 89
# 送別 , 501 , 8
# 為Y取名、字 , 535 , 14
# 戰友 , 404 , 105
# 為Y之家傳作序 , 579 , 1
# 王安石新法反對者 , 74 , 19
# 反對/攻訐 , 15 , 334

# %%
from collections import defaultdict
def statistic_social_status():
    '''
    统计社会地位
    PersonEntryInfo"->"Entry"->"RuShiDoor" : "正常科舉",
    PersonPostings" -> PersonSocialStatus"-> "SocialStatus"
    '''
    entry_dict = defaultdict(int)
    social_status_dict = defaultdict(int)
    error = 0
    for fname in os.listdir(DATA_DIR):
        fpath = os.path.join(DATA_DIR, fname)
        with open(fpath) as f:
            try:
                json_data = json.load(f)
                # print(json_data)
                if 'Person' not in json_data['Package']['PersonAuthority']['PersonInfo']:
                    continue
                person_data = json_data['Package']['PersonAuthority']['PersonInfo']['Person']
                if 'PersonEntryInfo' in person_data and 'Entry' in person_data['PersonEntryInfo']:
                    tmp = person_data['PersonEntryInfo']['Entry']
                    if isinstance(tmp, list):
                        for tmp2 in tmp:
                            if 'RuShiDoor' in tmp2:
                                tmp3 = tmp2['RuShiDoor']
                                entry_dict[tmp3] += 1
                    else:
                        tmp3 = tmp['RuShiDoor']
                        entry_dict[tmp3] += 1
                if 'PersonSocialStatus' in person_data and 'SocialStatus' in person_data['PersonSocialStatus']:
                        tmp = person_data['PersonSocialStatus']['SocialStatus']
                        if isinstance(tmp, list):
                            for tmp2 in tmp:
                                tmp3 = tmp2['StatusName']
                                social_status_dict[tmp3] += 1
                        else:
                            tmp3 = tmp['StatusName']
                            social_status_dict[tmp3] += 1
            except json.decoder.JSONDecodeError as e:
                    error += 1
    print(error)
    print(entry_dict)
    print(social_status_dict)
statistic_social_status()
# Out:
# defaultdict(<class 'int'>, {'': 4343, '監生門': 3407, '宗教門': 42, '血親門': 1157, '姻親門': 47, '徵召門': 1137, '其他舉': 74, '求官不得門': 177, '正常科舉': 75716, '宮廷門': 278, '貢生門': 1424, '特旨門': 1910, '恩蔭門': 1712, '未知入仕途徑': 306, '進納門': 31, '非經常科舉': 311, '軍功補授門': 275, '歸降門': 43, 'Temp': 4, '其他入仕途徑': 78, '技進門': 29, '薦舉門': 681, '七色補官門': 32, '制舉': 441, '學生門': 2671}) defaultdict(<class 'int'>, {'': 5, '儒學': 305, '經學家—公羊學': 8, '[節度使]': 15, '書院山長': 295, '未仕而卒': 275, '工於古文': 104, '妾': 39, '義軍首領': 118, '工匠': 9, '父老;耆老': 24, '酷吏': 15, '[學生： 八行]': 8, '理學家': 713, '奴婢': 7, '落第士人': 275, '[]': 2, '醫學教授': 6, '[母]': 595, '教師：軍事教官': 40, '並稱/齊名': 16, '[正黃旗]': 5, '業進士': 140, '經學家—禮經': 129, '道士': 272, '好學': 354, '在室女': 4, '書法家': 872, '未婚而卒': 76, '建書院/義塾/家塾  ': 52, '[有官銜]': 239, '[鑲藍旗]': 1, '[刺史幕僚（知州幕僚）]': 6, '曲作家': 25, '天文學家（星象家）': 110, '[未婚妻]': 4, '[武學生]': 2, '作家': 2, '削籍官員': 176, '薩滿教巫師': 1, '目錄學家': 3, '主家事': 50, '[武官]': 2473, '酋長': 34, '精於戲劇': 9, '[皇帝]': 178, '[舉人]': 17, '腐儒': 1, '隱居授徒': 105, '刻工': 2, '門客': 38, '道姑(女冠)': 14, '地方士人/鄉紳': 1469, '譯書家': 5, '主書院講席': 27, '通曉外語': 46, '[鄉貢進士]': 76, '經學家—榖梁學': 7, '[財政官員]': 2787, '胥吏': 27, '精於拳法': 6, '[學生：生員]': 1, '[附貢]': 1, '武將': 763, '習於道術': 27, '小學家－音韻學': 11, '煉丹家': 14, '拒絕出仕': 384, '[宰相]': 229, '為邑里所重': 205, '考據學家': 32, '經學家—詩經': 33, '隱居不仕': 115, '遺民': 75, '小學家': 35, '軍卒': 8, '收徒講學': 566, '經學家': 332, '博學之人': 361, '法律專家': 34, '[正紅旗]': 3, '處士': 117, '外交': 1, '[皇后]': 17, '水利專家': 52, '版本學家': 5, '[例貢]': 1, '建築家 — 園林設計': 9, '行醫': 235, '小學家－說文': 8, '收藏家': 28, '農學家': 10, '植物學家': 2, '經學家—春秋': 203, '布衣': 123, '貞婦': 104, '統治者': 53, '[隱居（有隱德）]': 540, '[醫官]': 33, '醫學': 62, '[貴族]': 58, '官伎': 2, '思想家': 2, '精通詩(詞曲)之聲韻音律': 22, '[廩員]': 2, '數學家': 53, '未參加科舉而卒': 189, '鄉里長者': 43, '音樂學家': 61, '[正白旗]': 4, '卜筮者（太乙、軌革、六壬、遁甲等）': 56, '經學家—今文經學': 3, '[縣學生]': 7, '[軍事將校]': 6, '陰陽家': 43, '比丘尼': 13, '[貢生]': 1, '不求仕': 196, '[鮮卑可汗]': 2, '義門': 87, '工於駢體文': 26, '文人': 318, '[太尉（漢）]': 1, '[未詳]': 30, '語言學家': 5, '詩人': 4221, '鑒賞家': 30, '長於制舉之文': 3, '熟諳兵法韜略': 137, '篆刻家': 18, '教育家': 24, '藏書家': 144, '堪輿家風水師': 22, '包攬?': 2, '妓': 30, '死國難': 666, '相面相手者': 3, '為善鄉里': 106, '政治家': 12, '[后妃]': 16, '[幕僚]': 1, '[妻]': 599, '[內命婦]': 26, '主動放棄科舉': 44, '經世學者': 38, '生物學家': 2, '經學家—漢學': 10, '[諸生]': 59, '[幕官]': 4, '耶穌會士': 2, '華僑': 1, '工於作賦': 205, '小學家－訓詁學': 18, '詞人': 183, '叛臣': 42, '圍棋棋手': 12, '[增廣生員]': 7, '[學官]': 77, '精於某種兵器': 16, '[外命婦]': 469, '經學家—左傳': 38, '以瞽廢': 1, '軍閥': 3, '校堪學家': 75, '精於騎射': 152, '富豪': 530, '曾被流放': 1, '[低級官僚]': 17, '科學家': 4, '家有田產': 29, '宗子': 520, '劊子手': 2, '史學家': 373, '良吏;循吏': 818, '[監生]': 1, '侍女': 2, '結社': 219, '[隱士]': 136, '學者': 30, '出版家': 1, '佛教之俗家弟子': 5, '精於劍術': 15, '畫家': 1290, '刻書家': 4, '食素': 27, '農民': 245, '孝子/孝女': 892, '地理學家': 62, '僧人': 1219, '甲骨文專家': 7, '強記;博學強記': 88, '求仕': 3, '工於文': 1224, '外戚': 103, '[府州學教授]': 13, '鄉先生': 127, '以疾廢': 371, '金石學家': 53, '[預鄉薦]': 1, '隱居道士': 16, '[大帥]': 3, '歸正人': 1, '[供奉內廷]': 11, '精通西學': 1, '家塾師': 32, '士人': 984, '小學家－字學': 8, '小說家': 14, '早卒(未成年而卒)': 148, '[太學生]': 184, '歸明人': 3, '翻譯': 3, '精於箭術': 7, '經學家—易經': 208, '樂人': 1, '徵至京師': 76, '牙將': 9, '熟諳水務海戰': 14, '罪犯': 6, '[宰執]': 457, '[為官者：文]': 16984, '[稅務官]': 1, '宦官': 165, '[季父房]': 7, '管理田產': 13, '天師': 18, '哲學家': 7, '雕繪鐫刻家': 1, '曆算家': 49, '[進士]': 158, '[鑲黃旗]': 7, '經學家—尚書': 89, '商人': 24, '理學家 — 陽明學派': 81, '精於某種樂器': 44, '[推薦參加制科]': 1, '外文學家': 1, '[捐納得官]': 1})
# 1
# defaultdict(<class 'int'>, {'': 4343, '監生門': 3407, '宗教門': 42, '血親門': 1157, '姻親門': 47, '徵召門': 1137, '其他舉': 74, '求官不得門': 177, '正常科舉': 75716, '宮廷門': 278, '貢生門': 1424, '特旨門': 1910, '恩蔭門': 1712, '未知入仕途徑': 306, '進納門': 31, '非經常科舉': 311, '軍功補授門': 275, '歸降門': 43, 'Temp': 4, '其他入仕途徑': 78, '技進門': 29, '薦舉門': 681, '七色補官門': 32, '制舉': 441, '學生門': 2671})
# defaultdict(<class 'int'>, {'': 5, '儒學': 305, '經學家—公羊學': 8, '[節度使]': 15, '書院山長': 295, '未仕而卒': 275, '工於古文': 104, '妾': 39, '義軍首領': 118, '工匠': 9, '父老;耆老': 24, '酷吏': 15, '[學生： 八行]': 8, '理學家': 713, '奴婢': 7, '落第士人': 275, '[]': 2, '醫學教授': 6, '[母]': 595, '教師：軍事教官': 40, '並稱/齊名': 16, '[正黃旗]': 5, '業進士': 140, '經學家—禮經': 129, '道士': 272, '好學': 354, '在室女': 4, '書法家': 872, '未婚而卒': 76, '建書院/義塾/家塾  ': 52, '[有官銜]': 239, '[鑲藍旗]': 1, '[刺史幕僚（知州幕僚）]': 6, '曲作家': 25, '天文學家（星象家）': 110, '[未婚妻]': 4, '[武學生]': 2, '作家': 2, '削籍官員': 176, '薩滿教巫師': 1, '目錄學家': 3, '主家事': 50, '[武官]': 2473, '酋長': 34, '精於戲劇': 9, '[皇帝]': 178, '[舉人]': 17, '腐儒': 1, '隱居授徒': 105, '刻工': 2, '門客': 38, '道姑(女冠)': 14, '地方士人/鄉紳': 1469, '譯書家': 5, '主書院講席': 27, '通曉外語': 46, '[鄉貢進士]': 76, '經學家—榖梁學': 7, '[財政官員]': 2787, '胥吏': 27, '精於拳法': 6, '[學生：生員]': 1, '[附貢]': 1, '武將': 763, '習於道術': 27, '小學家－音韻學': 11, '煉丹家': 14, '拒絕出仕': 384, '[宰相]': 229, '為邑里所重': 205, '考據學家': 32, '經學家—詩經': 33, '隱居不仕': 115, '遺民': 75, '小學家': 35, '軍卒': 8, '收徒講學': 566, '經學家': 332, '博學之人': 361, '法律專家': 34, '[正紅旗]': 3, '處士': 117, '外交': 1, '[皇后]': 17, '水利專家': 52, '版本學家': 5, '[例貢]': 1, '建築家 — 園林設計': 9, '行醫': 235, '小學家－說文': 8, '收藏家': 28, '農學家': 10, '植物學家': 2, '經學家—春秋': 203, '布衣': 123, '貞婦': 104, '統治者': 53, '[隱居（有隱德）]': 540, '[醫官]': 33, '醫學': 62, '[貴族]': 58, '官伎': 2, '思想家': 2, '精通詩(詞曲)之聲韻音律': 22, '[廩員]': 2, '數學家': 53, '未參加科舉而卒': 189, '鄉里長者': 43, '音樂學家': 61, '[正白旗]': 4, '卜筮者（太乙、軌革、六壬、遁甲等）': 56, '經學家—今文經學': 3, '[縣學生]': 7, '[軍事將校]': 6, '陰陽家': 43, '比丘尼': 13, '[貢生]': 1, '不求仕': 196, '[鮮卑可汗]': 2, '義門': 87, '工於駢體文': 26, '文人': 318, '[太尉（漢）]': 1, '[未詳]': 30, '語言學家': 5, '詩人': 4221, '鑒賞家': 30, '長於制舉之文': 3, '熟諳兵法韜略': 137, '篆刻家': 18, '教育家': 24, '藏書家': 144, '堪輿家風水師': 22, '包攬?': 2, '妓': 30, '死國難': 666, '相面相手者': 3, '為善鄉里': 106, '政治家': 12, '[后妃]': 16, '[幕僚]': 1, '[妻]': 599, '[內命婦]': 26, '主動放棄科舉': 44, '經世學者': 38, '生物學家': 2, '經學家—漢學': 10, '[諸生]': 59, '[幕官]': 4, '耶穌會士': 2, '華僑': 1, '工於作賦': 205, '小學家－訓詁學': 18, '詞人': 183, '叛臣': 42, '圍棋棋手': 12, '[增廣生員]': 7, '[學官]': 77, '精於某種兵器': 16, '[外命婦]': 469, '經學家—左傳': 38, '以瞽廢': 1, '軍閥': 3, '校堪學家': 75, '精於騎射': 152, '富豪': 530, '曾被流放': 1, '[低級官僚]': 17, '科學家': 4, '家有田產': 29, '宗子': 520, '劊子手': 2, '史學家': 373, '良吏;循吏': 818, '[監生]': 1, '侍女': 2, '結社': 219, '[隱士]': 136, '學者': 30, '出版家': 1, '佛教之俗家弟子': 5, '精於劍術': 15, '畫家': 1290, '刻書家': 4, '食素': 27, '農民': 245, '孝子/孝女': 892, '地理學家': 62, '僧人': 1219, '甲骨文專家': 7, '強記;博學強記': 88, '求仕': 3, '工於文': 1224, '外戚': 103, '[府州學教授]': 13, '鄉先生': 127, '以疾廢': 371, '金石學家': 53, '[預鄉薦]': 1, '隱居道士': 16, '[大帥]': 3, '歸正人': 1, '[供奉內廷]': 11, '精通西學': 1, '家塾師': 32, '士人': 984, '小學家－字學': 8, '小說家': 14, '早卒(未成年而卒)': 148, '[太學生]': 184, '歸明人': 3, '翻譯': 3, '精於箭術': 7, '經學家—易經': 208, '樂人': 1, '徵至京師': 76, '牙將': 9, '熟諳水務海戰': 14, '罪犯': 6, '[宰執]': 457, '[為官者：文]': 16984, '[稅務官]': 1, '宦官': 165, '[季父房]': 7, '管理田產': 13, '天師': 18, '哲學家': 7, '雕繪鐫刻家': 1, '曆算家': 49, '[進士]': 158, '[鑲黃旗]': 7, '經學家—尚書': 89, '商人': 24, '理學家 — 陽明學派': 81, '精於某種樂器': 44, '[推薦參加制科]': 1, '外文學家': 1, '[捐納得官]': 1})
